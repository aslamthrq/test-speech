# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # to use operating system dependent functionality
import librosa # to extract speech features
import wave # read and write WAV files
import matplotlib.pyplot as plt # to generate the visualizations

# MLP Classifier
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# LSTM Classifier
import keras
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import *
from keras.optimizers import rmsprop

# %%
def extract_mfcc(wav_file_name):
    #This function extracts mfcc features and obtain the mean of each dimension
    #Input : path_to_wav_file
    #Output: mfcc_features'''
    y, sr = librosa.load(wav_file_name)
    mfccs = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T,axis=0)
    
    return mfccs

# %%
##### load radvess speech data #####
radvess_speech_labels = [] # to save extracted label/file
ravdess_speech_data = [] # to save extracted features/file
for dirname, _, filenames in os.walk('/kaggle/input/ravdess-emotional-speech-audio'):
    for filename in filenames:
        #print(os.path.join(dirname, filename))
        radvess_speech_labels.append(int(filename[7:8]) - 1) # the index 7 and 8 of the file name represent the emotion label
        wav_file_name = os.path.join(dirname, filename)
        ravdess_speech_data.append(extract_mfcc(wav_file_name)) # extract MFCC features/file
        
print("Finish Loading the Dataset")
# Out:
# Finish Loading the Dataset

# %%
#### convert data and label to array
ravdess_speech_data_array = np.asarray(ravdess_speech_data) # convert the input to an array
ravdess_speech_label_array = np.array(radvess_speech_labels)
ravdess_speech_label_array.shape # get tuple of array dimensions

#### make categorical labels
labels_categorical = to_categorical(ravdess_speech_label_array) # converts a class vector (integers) to binary class matrix
labels_categorical.shape
# Out:
# (2880, 8)

# %%
ravdess_speech_data_array.shape
# Out:
# (2880, 40)

# %%
x_train,x_test,y_train,y_test= train_test_split(np.array(ravdess_speech_data_array),labels_categorical, test_size=0.20, random_state=9)

# %%
# Split the training, validating, and testing sets
number_of_samples = ravdess_speech_data_array.shape[0]
training_samples = int(number_of_samples * 0.8)
validation_samples = int(number_of_samples * 0.1)
test_samples = int(number_of_samples * 0.1)

# %%
# Define the LSTM model
def create_model_LSTM():
    model = Sequential()
    model.add(LSTM(128, return_sequences=False, input_shape=(40, 1)))
    model.add(Dense(64))
    model.add(Dropout(0.4))
    model.add(Activation('relu'))
    model.add(Dense(32))
    model.add(Dropout(0.4))
    model.add(Activation('relu'))
    model.add(Dense(8))
    model.add(Activation('softmax'))
    
    # Configures the model for training
    model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
    return model

# %%
w = np.expand_dims(ravdess_speech_data_array[:training_samples],-1)

# %%
w.shape
# Out:
# (2304, 40, 1)

# %%
### train using LSTM model
model_A = create_model_LSTM()
history = model_A.fit(np.expand_dims(ravdess_speech_data_array[:training_samples],-1), labels_categorical[:training_samples], validation_data=(np.expand_dims(ravdess_speech_data_array[training_samples:training_samples+validation_samples], -1), labels_categorical[training_samples:training_samples+validation_samples]), epochs=121, shuffle=True)
# Out:
# Epoch 1/121
# 72/72 [==============================] - 6s 46ms/step - loss: 2.0692 - accuracy: 0.1523 - val_loss: 2.0320 - val_accuracy: 0.1944
# Epoch 2/121
# 72/72 [==============================] - 3s 38ms/step - loss: 2.0110 - accuracy: 0.1914 - val_loss: 1.9709 - val_accuracy: 0.2049
# Epoch 3/121
# 72/72 [==============================] - 3s 41ms/step - loss: 1.9141 - accuracy: 0.2474 - val_loss: 1.9386 - val_accuracy: 0.2778
# Epoch 4/121
# 72/72 [==============================] - 3s 39ms/step - loss: 1.8971 - accuracy: 0.2604 - val_loss: 1.8655 - val_accuracy: 0.2674
# Epoch 5/121
# 72/72 [==============================] - 3s 38ms/step - loss: 1.8455 - accuracy: 0.2839 - val_loss: 1.8958 - val_accuracy: 0.2604
# Epoch 6/121
# 72/72 [==============================] - 3s 38ms/step - loss: 1.8216 - accuracy: 0.2995 - val_loss: 1.9110 - val_accuracy: 0.2812
# Epoch 7/121
# 72/72 [==============================] - 3s 40ms/step - loss: 1.8239 - accuracy: 0.2934 - val_loss: 1.8793 - val_accuracy: 0.2847
# Epoch 8/121
# 72/72 [==============================] - 3s 44ms/step - loss: 1.7923 - accuracy: 0.3229 - val_loss: 1.9204 - val_accuracy: 0.2812
# Epoch 9/121
# 72/72 [==============================] - 3s 40ms/step - loss: 1.7776 - accuracy: 0.3021 - val_loss: 1.8752 - val_accuracy: 0.2465
# Epoch 10/121
# 72/72 [==============================] - 3s 38ms/step - loss: 1.7559 - accuracy: 0.3142 - val_loss: 1.9572 - val_accuracy: 0.2361
# Epoch 11/121
# 72/72 [==============================] - 3s 38ms/step - loss: 1.7427 - accuracy: 0.3329 - val_loss: 1.9271 - val_accuracy: 0.2847
# Epoch 12/121
# 72/72 [==============================] - 3s 37ms/step - loss: 1.7153 - accuracy: 0.3416 - val_loss: 1.9526 - val_accuracy: 0.2778
# Epoch 13/121
# 72/72 [==============================] - 3s 37ms/step - loss: 1.7042 - accuracy: 0.3385 - val_loss: 1.8561 - val_accuracy: 0.2500
# Epoch 14/121
# 72/72 [==============================] - 3s 40ms/step - loss: 1.6650 - accuracy: 0.3494 - val_loss: 1.9239 - val_accuracy: 0.2674
# Epoch 15/121
# 72/72 [==============================] - 3s 38ms/step - loss: 1.6246 - accuracy: 0.3681 - val_loss: 1.8690 - val_accuracy: 0.3056
# Epoch 16/121
# 72/72 [==============================] - 3s 37ms/step - loss: 1.6003 - accuracy: 0.3815 - val_loss: 1.9001 - val_accuracy: 0.3056
# Epoch 17/121
# 72/72 [==============================] - 3s 37ms/step - loss: 1.5941 - accuracy: 0.3845 - val_loss: 1.9060 - val_accuracy: 0.3264
# Epoch 18/121
# 72/72 [==============================] - 3s 38ms/step - loss: 1.5795 - accuracy: 0.3802 - val_loss: 1.9703 - val_accuracy: 0.2986
# Epoch 19/121
# 72/72 [==============================] - 3s 39ms/step - loss: 1.5533 - accuracy: 0.3984 - val_loss: 1.9673 - val_accuracy: 0.2917
# Epoch 20/121
# 72/72 [==============================] - 3s 38ms/step - loss: 1.4849 - accuracy: 0.4253 - val_loss: 1.9526 - val_accuracy: 0.2778
# Epoch 21/121
# 72/72 [==============================] - 3s 38ms/step - loss: 1.4741 - accuracy: 0.4249 - val_loss: 1.9853 - val_accuracy: 0.3125
# Epoch 22/121
# 72/72 [==============================] - 3s 37ms/step - loss: 1.4635 - accuracy: 0.4258 - val_loss: 1.9118 - val_accuracy: 0.3090
# Epoch 23/121
# 72/72 [==============================] - 3s 37ms/step - loss: 1.4321 - accuracy: 0.4405 - val_loss: 2.0035 - val_accuracy: 0.2951
# Epoch 24/121
# 72/72 [==============================] - 3s 37ms/step - loss: 1.4159 - accuracy: 0.4657 - val_loss: 1.9726 - val_accuracy: 0.3229
# Epoch 25/121
# 72/72 [==============================] - 3s 38ms/step - loss: 1.3890 - accuracy: 0.4670 - val_loss: 1.9904 - val_accuracy: 0.2917
# Epoch 26/121
# 72/72 [==============================] - 3s 37ms/step - loss: 1.3761 - accuracy: 0.4622 - val_loss: 2.1606 - val_accuracy: 0.2986
# Epoch 27/121
# 72/72 [==============================] - 3s 39ms/step - loss: 1.3412 - accuracy: 0.4800 - val_loss: 2.0751 - val_accuracy: 0.2882
# Epoch 28/121
# 72/72 [==============================] - 3s 40ms/step - loss: 1.3461 - accuracy: 0.4809 - val_loss: 2.0283 - val_accuracy: 0.3333
# Epoch 29/121
# 72/72 [==============================] - 3s 38ms/step - loss: 1.2719 - accuracy: 0.5048 - val_loss: 2.2451 - val_accuracy: 0.2882
# Epoch 30/121
# 72/72 [==============================] - 3s 38ms/step - loss: 1.2595 - accuracy: 0.5065 - val_loss: 2.1675 - val_accuracy: 0.2847
# Epoch 31/121
# 72/72 [==============================] - 3s 41ms/step - loss: 1.2126 - accuracy: 0.5217 - val_loss: 2.1726 - val_accuracy: 0.3264
# Epoch 32/121
# 72/72 [==============================] - 3s 38ms/step - loss: 1.2611 - accuracy: 0.5113 - val_loss: 2.2522 - val_accuracy: 0.3090
# Epoch 33/121
# 72/72 [==============================] - 3s 38ms/step - loss: 1.1889 - accuracy: 0.5326 - val_loss: 2.3145 - val_accuracy: 0.3160
# Epoch 34/121
# 72/72 [==============================] - 3s 38ms/step - loss: 1.1737 - accuracy: 0.5460 - val_loss: 2.2058 - val_accuracy: 0.3194
# Epoch 35/121
# 72/72 [==============================] - 3s 37ms/step - loss: 1.0930 - accuracy: 0.5755 - val_loss: 2.2320 - val_accuracy: 0.3368
# Epoch 36/121
# 72/72 [==============================] - 3s 38ms/step - loss: 1.0904 - accuracy: 0.5820 - val_loss: 2.3685 - val_accuracy: 0.2847
# Epoch 37/121
# 72/72 [==============================] - 3s 38ms/step - loss: 1.0653 - accuracy: 0.5781 - val_loss: 2.6294 - val_accuracy: 0.3056
# Epoch 38/121
# 72/72 [==============================] - 3s 38ms/step - loss: 1.0262 - accuracy: 0.6042 - val_loss: 2.4120 - val_accuracy: 0.2917
# Epoch 39/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.9968 - accuracy: 0.6159 - val_loss: 2.5124 - val_accuracy: 0.3507
# Epoch 40/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.9622 - accuracy: 0.6306 - val_loss: 2.7184 - val_accuracy: 0.2986
# Epoch 41/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.9683 - accuracy: 0.6194 - val_loss: 2.7924 - val_accuracy: 0.3125
# Epoch 42/121
# 72/72 [==============================] - 3s 41ms/step - loss: 0.8867 - accuracy: 0.6536 - val_loss: 2.8067 - val_accuracy: 0.3125
# Epoch 43/121
# 72/72 [==============================] - 3s 45ms/step - loss: 0.8525 - accuracy: 0.6658 - val_loss: 2.9171 - val_accuracy: 0.3160
# Epoch 44/121
# 72/72 [==============================] - 3s 48ms/step - loss: 0.9013 - accuracy: 0.6502 - val_loss: 2.8272 - val_accuracy: 0.3194
# Epoch 45/121
# 72/72 [==============================] - 3s 48ms/step - loss: 0.9250 - accuracy: 0.6532 - val_loss: 3.2104 - val_accuracy: 0.3160
# Epoch 46/121
# 72/72 [==============================] - 4s 50ms/step - loss: 0.7805 - accuracy: 0.7036 - val_loss: 3.1093 - val_accuracy: 0.3090
# Epoch 47/121
# 72/72 [==============================] - 4s 51ms/step - loss: 0.7668 - accuracy: 0.7144 - val_loss: 3.2895 - val_accuracy: 0.2569
# Epoch 48/121
# 72/72 [==============================] - 4s 49ms/step - loss: 0.7006 - accuracy: 0.7326 - val_loss: 3.6739 - val_accuracy: 0.3125
# Epoch 49/121
# 72/72 [==============================] - 3s 44ms/step - loss: 0.6556 - accuracy: 0.7431 - val_loss: 3.8704 - val_accuracy: 0.3056
# Epoch 50/121
# 72/72 [==============================] - 3s 45ms/step - loss: 0.6363 - accuracy: 0.7574 - val_loss: 4.0172 - val_accuracy: 0.2847
# Epoch 51/121
# 72/72 [==============================] - 3s 47ms/step - loss: 0.6668 - accuracy: 0.7543 - val_loss: 3.7434 - val_accuracy: 0.2986
# Epoch 52/121
# 72/72 [==============================] - 4s 50ms/step - loss: 0.5781 - accuracy: 0.7795 - val_loss: 3.9989 - val_accuracy: 0.2986
# Epoch 53/121
# 72/72 [==============================] - 3s 42ms/step - loss: 0.6471 - accuracy: 0.7609 - val_loss: 4.0553 - val_accuracy: 0.2986
# Epoch 54/121
# 72/72 [==============================] - 3s 42ms/step - loss: 0.6504 - accuracy: 0.7617 - val_loss: 3.9586 - val_accuracy: 0.2743
# Epoch 55/121
# 72/72 [==============================] - 3s 42ms/step - loss: 0.6283 - accuracy: 0.7726 - val_loss: 4.1536 - val_accuracy: 0.2847
# Epoch 56/121
# 72/72 [==============================] - 3s 44ms/step - loss: 0.6934 - accuracy: 0.7478 - val_loss: 4.5020 - val_accuracy: 0.2917
# Epoch 57/121
# 72/72 [==============================] - 3s 46ms/step - loss: 0.4763 - accuracy: 0.8216 - val_loss: 4.5493 - val_accuracy: 0.3056
# Epoch 58/121
# 72/72 [==============================] - 3s 42ms/step - loss: 0.4723 - accuracy: 0.8264 - val_loss: 4.8645 - val_accuracy: 0.3194
# Epoch 59/121
# 72/72 [==============================] - 3s 40ms/step - loss: 0.4724 - accuracy: 0.8264 - val_loss: 4.7721 - val_accuracy: 0.3021
# Epoch 60/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.4571 - accuracy: 0.8303 - val_loss: 4.9822 - val_accuracy: 0.2951
# Epoch 61/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.4135 - accuracy: 0.8481 - val_loss: 5.1447 - val_accuracy: 0.2951
# Epoch 62/121
# 72/72 [==============================] - 3s 40ms/step - loss: 0.4327 - accuracy: 0.8464 - val_loss: 4.7931 - val_accuracy: 0.2917
# Epoch 63/121
# 72/72 [==============================] - 3s 39ms/step - loss: 0.5912 - accuracy: 0.7990 - val_loss: 4.6289 - val_accuracy: 0.2674
# Epoch 64/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.6660 - accuracy: 0.7782 - val_loss: 4.6123 - val_accuracy: 0.2708
# Epoch 65/121
# 72/72 [==============================] - 3s 39ms/step - loss: 0.3608 - accuracy: 0.8715 - val_loss: 5.1178 - val_accuracy: 0.2882
# Epoch 66/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.3198 - accuracy: 0.8815 - val_loss: 5.6539 - val_accuracy: 0.2812
# Epoch 67/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.3534 - accuracy: 0.8707 - val_loss: 5.4715 - val_accuracy: 0.2986
# Epoch 68/121
# 72/72 [==============================] - 3s 37ms/step - loss: 0.3937 - accuracy: 0.8702 - val_loss: 5.7361 - val_accuracy: 0.2951
# Epoch 69/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.3351 - accuracy: 0.8815 - val_loss: 5.5404 - val_accuracy: 0.2986
# Epoch 70/121
# 72/72 [==============================] - 3s 39ms/step - loss: 0.3597 - accuracy: 0.8763 - val_loss: 5.8086 - val_accuracy: 0.3056
# Epoch 71/121
# 72/72 [==============================] - 3s 37ms/step - loss: 0.2754 - accuracy: 0.9045 - val_loss: 6.0713 - val_accuracy: 0.2882
# Epoch 72/121
# 72/72 [==============================] - 3s 40ms/step - loss: 0.3041 - accuracy: 0.9015 - val_loss: 6.5269 - val_accuracy: 0.2847
# Epoch 73/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.4314 - accuracy: 0.8641 - val_loss: 5.9443 - val_accuracy: 0.2708
# Epoch 74/121
# 72/72 [==============================] - 3s 42ms/step - loss: 0.3844 - accuracy: 0.8728 - val_loss: 5.8635 - val_accuracy: 0.2847
# Epoch 75/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.2408 - accuracy: 0.9197 - val_loss: 6.1654 - val_accuracy: 0.2812
# Epoch 76/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.1830 - accuracy: 0.9392 - val_loss: 6.8404 - val_accuracy: 0.2882
# Epoch 77/121
# 72/72 [==============================] - 3s 37ms/step - loss: 0.2093 - accuracy: 0.9297 - val_loss: 6.8407 - val_accuracy: 0.3056
# Epoch 78/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.2037 - accuracy: 0.9258 - val_loss: 7.4600 - val_accuracy: 0.3021
# Epoch 79/121
# 72/72 [==============================] - 3s 37ms/step - loss: 0.3155 - accuracy: 0.9006 - val_loss: 7.2820 - val_accuracy: 0.2674
# Epoch 80/121
# 72/72 [==============================] - 3s 37ms/step - loss: 0.4231 - accuracy: 0.8655 - val_loss: 5.6303 - val_accuracy: 0.2986
# Epoch 81/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.2967 - accuracy: 0.9028 - val_loss: 6.2623 - val_accuracy: 0.2847
# Epoch 82/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.1904 - accuracy: 0.9375 - val_loss: 6.7051 - val_accuracy: 0.2986
# Epoch 83/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.1589 - accuracy: 0.9501 - val_loss: 7.2855 - val_accuracy: 0.2812
# Epoch 84/121
# 72/72 [==============================] - 3s 37ms/step - loss: 0.1424 - accuracy: 0.9527 - val_loss: 7.9293 - val_accuracy: 0.2778
# Epoch 85/121
# 72/72 [==============================] - 3s 39ms/step - loss: 0.3165 - accuracy: 0.9106 - val_loss: 6.2947 - val_accuracy: 0.2743
# Epoch 86/121
# 72/72 [==============================] - 3s 40ms/step - loss: 0.2652 - accuracy: 0.9115 - val_loss: 7.2486 - val_accuracy: 0.2674
# Epoch 87/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.3143 - accuracy: 0.9080 - val_loss: 6.8759 - val_accuracy: 0.2778
# Epoch 88/121
# 72/72 [==============================] - 3s 37ms/step - loss: 0.2056 - accuracy: 0.9366 - val_loss: 7.2027 - val_accuracy: 0.3090
# Epoch 89/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.1332 - accuracy: 0.9540 - val_loss: 7.5154 - val_accuracy: 0.2708
# Epoch 90/121
# 72/72 [==============================] - 3s 37ms/step - loss: 0.1247 - accuracy: 0.9661 - val_loss: 7.8206 - val_accuracy: 0.2847
# Epoch 91/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.1299 - accuracy: 0.9631 - val_loss: 8.2164 - val_accuracy: 0.2951
# Epoch 92/121
# 72/72 [==============================] - 3s 37ms/step - loss: 0.1207 - accuracy: 0.9653 - val_loss: 8.3692 - val_accuracy: 0.2951
# Epoch 93/121
# 72/72 [==============================] - 3s 37ms/step - loss: 0.1932 - accuracy: 0.9484 - val_loss: 8.1078 - val_accuracy: 0.3056
# Epoch 94/121
# 72/72 [==============================] - 3s 37ms/step - loss: 0.5640 - accuracy: 0.8403 - val_loss: 6.9587 - val_accuracy: 0.2882
# Epoch 95/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.3121 - accuracy: 0.9023 - val_loss: 6.7262 - val_accuracy: 0.2847
# Epoch 96/121
# 72/72 [==============================] - 3s 37ms/step - loss: 0.2360 - accuracy: 0.9301 - val_loss: 7.2094 - val_accuracy: 0.2847
# Epoch 97/121
# 72/72 [==============================] - 3s 40ms/step - loss: 0.1302 - accuracy: 0.9588 - val_loss: 7.8111 - val_accuracy: 0.3056
# Epoch 98/121
# 72/72 [==============================] - 3s 39ms/step - loss: 0.1071 - accuracy: 0.9709 - val_loss: 7.8760 - val_accuracy: 0.2812
# Epoch 99/121
# 72/72 [==============================] - 3s 40ms/step - loss: 0.0920 - accuracy: 0.9714 - val_loss: 8.5034 - val_accuracy: 0.3333
# Epoch 100/121
# 72/72 [==============================] - 3s 36ms/step - loss: 0.0712 - accuracy: 0.9813 - val_loss: 8.6274 - val_accuracy: 0.2951
# Epoch 101/121
# 72/72 [==============================] - 3s 37ms/step - loss: 0.1167 - accuracy: 0.9692 - val_loss: 8.9757 - val_accuracy: 0.2812
# Epoch 102/121
# 72/72 [==============================] - 3s 37ms/step - loss: 0.1571 - accuracy: 0.9562 - val_loss: 8.2465 - val_accuracy: 0.3160
# Epoch 103/121
# 72/72 [==============================] - 3s 36ms/step - loss: 0.3088 - accuracy: 0.9158 - val_loss: 7.2606 - val_accuracy: 0.2917
# Epoch 104/121
# 72/72 [==============================] - 3s 37ms/step - loss: 0.2048 - accuracy: 0.9401 - val_loss: 7.5545 - val_accuracy: 0.3056
# Epoch 105/121
# 72/72 [==============================] - 3s 37ms/step - loss: 0.2370 - accuracy: 0.9388 - val_loss: 7.1250 - val_accuracy: 0.3021
# Epoch 106/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.1143 - accuracy: 0.9661 - val_loss: 7.7697 - val_accuracy: 0.2882
# Epoch 107/121
# 72/72 [==============================] - 3s 37ms/step - loss: 0.0890 - accuracy: 0.9748 - val_loss: 8.3296 - val_accuracy: 0.2847
# Epoch 108/121
# 72/72 [==============================] - 3s 39ms/step - loss: 0.1060 - accuracy: 0.9714 - val_loss: 8.3272 - val_accuracy: 0.2986
# Epoch 109/121
# 72/72 [==============================] - 3s 42ms/step - loss: 0.2884 - accuracy: 0.9284 - val_loss: 7.5322 - val_accuracy: 0.3160
# Epoch 110/121
# 72/72 [==============================] - 3s 39ms/step - loss: 0.2739 - accuracy: 0.9232 - val_loss: 7.4103 - val_accuracy: 0.2674
# Epoch 111/121
# 72/72 [==============================] - 3s 37ms/step - loss: 0.1555 - accuracy: 0.9583 - val_loss: 7.8884 - val_accuracy: 0.2812
# Epoch 112/121
# 72/72 [==============================] - 3s 43ms/step - loss: 0.1135 - accuracy: 0.9705 - val_loss: 8.0458 - val_accuracy: 0.2674
# Epoch 113/121
# 72/72 [==============================] - 3s 44ms/step - loss: 0.1084 - accuracy: 0.9696 - val_loss: 8.4568 - val_accuracy: 0.2882
# Epoch 114/121
# 72/72 [==============================] - 3s 41ms/step - loss: 0.0702 - accuracy: 0.9822 - val_loss: 9.0346 - val_accuracy: 0.2778
# Epoch 115/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.0478 - accuracy: 0.9883 - val_loss: 9.3050 - val_accuracy: 0.2917
# Epoch 116/121
# 72/72 [==============================] - 3s 39ms/step - loss: 0.0496 - accuracy: 0.9887 - val_loss: 9.5265 - val_accuracy: 0.2674
# Epoch 117/121
# 72/72 [==============================] - 3s 37ms/step - loss: 0.0469 - accuracy: 0.9874 - val_loss: 9.9284 - val_accuracy: 0.2917
# Epoch 118/121
# 72/72 [==============================] - 3s 38ms/step - loss: 0.0464 - accuracy: 0.9874 - val_loss: 10.1424 - val_accuracy: 0.2812
# Epoch 119/121
# 72/72 [==============================] - 3s 36ms/step - loss: 0.0462 - accuracy: 0.9878 - val_loss: 10.3932 - val_accuracy: 0.2708
# Epoch 120/121
# 72/72 [==============================] - 3s 41ms/step - loss: 0.0633 - accuracy: 0.9839 - val_loss: 10.0585 - val_accuracy: 0.2743
# Epoch 121/121
# 72/72 [==============================] - 3s 39ms/step - loss: 0.0699 - accuracy: 0.9792 - val_loss: 9.9291 - val_accuracy: 0.2812

# %%
### loss plots using LSTM model
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
### accuracy plots using LSTM model
plt.clf()                                                

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'ro', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
### evaluate using model A
model_A.evaluate(np.expand_dims(ravdess_speech_data_array[training_samples + validation_samples:], -1), labels_categorical[training_samples + validation_samples:])

# %%
emotions={1 : 'neutral', 2 : 'calm', 3 : 'happy', 4 : 'sad', 5 : 'angry', 6 : 'fearful', 7 : 'disgust', 8 : 'surprised'}
def predict(wav_filepath):
  test_point=extract_mfcc(wav_filepath)
  test_point=np.reshape(test_point,newshape=(1,40,1))
  predictions=model_A.predict(test_point)
  print(emotions[np.argmax(predictions[0])+1])

# %%
predict('/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_sad/YAF_back_sad.wav')

# %%
model_A.save('mymodel.h5')

# %%
modelc=tf.keras.models.load_model('mymodel.h5')

# %%
predict('/akhil.wav')
